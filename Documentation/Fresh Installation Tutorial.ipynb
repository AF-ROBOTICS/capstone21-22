# %% [markdown]
# # Robotics Teaming Installation Tutorial
# ### ECE 495
# #### C1C Matthew U. DeMaso, C1C Anthony J. Tolbert
#
# ### Setting Up The NUC
# 1. The NUC comes with Ubuntu 20.04 and ROS already, so you will not need to worry about installing any of those packages.
# <br/>
#
# 1. Login:
#         Username: robotics***
#         Password: dfec3141
# <br/>
#
# 1. Open a new Terminal on the NUC <kbd>Ctrl</kbd>+<kbd>Alt</kbd>+<kbd>t</kbd>
# <br/>
#
# 1. Install the following libraries using *sudo apt install xxx*<br/>
#     1. rospy
#     1. time
#     1. signal
#     1. csv
#     1. copy
#     1. os
#     1. datetime
#     1. statistics
#     1. numpy
#
# ### Adding the NUC to the Network
#     There are two setups that have been used: An isolated local network and an internet enabled network (Makerspace). The main difference is the availability of a DHCP server, which is only available on the internet connected networks. Instalation is similar for each with key differences.
#
# 1. Connect to the network with the GUI (using \"Moku_Station_3_5Ghz\" as an example).
#
# #### Isolated LAN ONLY
#
# 1. Open the Wi-Fi settings to configure the IP settings:
#     1. Select the gear icon next to the network name
#
#     <img src="./Images/Gear.png">
#
#     1. Select the IPv4 tab and change IPv4 Method to "Manual"
#     1. Use the IP address format for your router (likely 192.168.1.xxx) to give the NUC a unique IP.
#     1. As of now the IP addresses are 192.168.1.2XX and 192.168.1.1XX for the NUCs and robots respectivly where XX is replaced with either the usafabot number or NUC number (i.e. robotics2 = 192.168.1.202 & usafabot22 = 192.168.1.122)
#     <img src="./Images/IPsettings.png">
#
# 1. Add other nodes' IP addresses to hosts file. The file can be copied from any of the other NUCs or robots, but the NUC should be added to the file first and copied to all NUCs and robots.
#     1. The file is located is */etc/hosts* and can be modified by nano with sudo permissions.
#     1. The file can also be pulled from the [capstone21-22](../src/hosts) or copied via SCP.
#
# <img src="./Images/hosts.png">
# <img src="./Images/hostsFile.png">

# %% [markdown]
# ### Setting Up the Robot
#
# The robot should come loaded with an image of Ubuntu that has the neccessary source files loaded. If not, contact Mr. Steven Beyer for the .iso file to be flashed to the raspberry pi. Ensure that the hostname matches the lablel and is what is expected. Hostnames can be updated by `hostnamectl set-hostname new-hostname`. Once the robot is added to the same network as the NUCs, updates to files can be accomplished via SCP.
#
# #### Adding the Robot to the Network
#     Adding a robot to the network is similar to the NUCs and should be done on the robots locally (not via SSH). Changes take effect after a reboot.
#
# 1. Connect the robot's Pi to a monitor and keyboard then turn it on.
#
# 1. After Ubuntu launches, Login:
#              Username: pi
#              Password: dfec3141
#
# 1. `sudo nano /etc/netplan/50-cloud-init.yaml` Change the network settings and IP address to match the robot
#
#     <img src="./Images/yamlFile.png">
#
# 1. Add other nodes' IP addresses to hosts file. The file can be copied from any of the other NUCs or robots, but the robot should be added to the file first and copied to all NUCs and robots.
#     1. The file is located is /etc/hosts and can be modified by nano with sudo permissions
#     1. The file can also be copied via SCP.

# %% [markdown]
#
# ## Downloading Files and Synching Device with GitHub
# 1. Ensure you have a working [GitHub](https://github.com) account.
#
#
# 1. Open a new Terminal on the NUC <kbd>Ctrl</kbd>+<kbd>Alt</kbd>+<kbd>t</kbd>
#
#
# 1. Generate a New SSH Key substituting your e-mail adress instead of ***mudemaso@gmail.com***
#
#    <img src="./Images/SSH_Keygen.png">
#
# 1. You will be prompted in which file to save the key. Press <kbd>Enter</kbd> when your terminal output is identical to the below picture.
#
#    <img src="./Images/SSH_Keygen2.png">
#
# 1. If a key already exists at the location, press <kbd>y</kbd>.
#
#    <img src="./Images/SSH_Keygen3.png">
#
# 1. Enter a new, easy to remember passphrase when prompted (***dfec3141***).
#
#    <img src="./Images/SSH_Keygen4.png">
#
# 1. Enter passphrase again when prompted. The final output should look like this.
#
#    <img src="./Images/SSH_Keygen5.png">
#
# 1. Run the following commands To ensure the SSH key is working properly and add in your new SSH ID. Enter the passcode when prompted. You should get a successfully added message when finished.
#
#    <img src="./Images/SSH_Add.png">
#
# 1. Open the Public Key.
#
#    <img src="./Images/SSH_PubKey.png">
#
# 1. Expand the Window to see the whole contents of the file (ends in your email). Copy The contents of the file. You must use right mouse, copy. <kbd>Ctrl</kbd>+<kbd>v</kbd>**DOES NOT WORK**
#
#
# 1. Open a web browser and sign into your GitHub Account.
#
#
# 1. In the top right-hand of the window, select the dropdown menu from your account picture and click on settings.
#
#   <img src="./Images/GitHub_Settings.png">
#
# 1. Open the ***SSH and GPG Keys*** section.
#
#   <img src="./Images/GitHub_Settings1.png">
#
# 1. Click new SSH Key.
#
#   <img src="./Images/GitHub_Settings3.png">
#
# 1. In the "Title" Field, put a descriptive title.
#
#
# 1. In the "Key" Field, paste the copied key from Step 10 into this field. When Finished, press "Add SSH Key".
#
#   <img src="./Images/GitHub_Settings4.png">
#
# 1. Navigate to the Capstone Reposity and click "Code". Copy the repo adress using SSH mode.
#
#   <img src="./Images/GitHub_Settings5.png">
#
# 1. In the File Browser Gui, navigate to *Home->robotics_ws->src*.
#
# 1. Ensure the "capstone21-22" folder is deleted.
#
# 1. Open a new Terminal on the NUC <kbd>Ctrl</kbd>+<kbd>Alt</kbd>+<kbd>t</kbd>
#
#
# 1. Navigate to the *robotics_ws->src* directory.
#
#     <img src="./Images/NavPath.png">
#
# 1. Clone the repo using the username and passphrase you used in Step 6 when prompted. Paste the repo adress from Step 11.
#
#     <img src="./Images/GitHub_Settings6.png">
#
# 1. Upon Completion the Repo is copied and you are now able to use all typical git commands from the terminal with the Repo!
#
#
# 1. Attain usafabot directory and gazebo directory from Dr. Baek / Mr. Beyer for simulations and working on real robot. Put them in your *robotics_ws->src directory*.

# %% [markdown]
# ### Create your ROS workspace:
# Source the ROS setup file:
# ```bash
# source /opt/ros/noetic/setup.bash
# ```
#
# ```bash
# mkdir -p ~/robotics_ws/src
# cd ~/robotics_ws/
# catkin_make
# ```
#
# Setup ROS environment variables and setup scripts within the `~/.bashrc` file. Open the `~/.bashrc` file with your favorite command line editor and add the following to the bottom:
#
# ```bash
# source /opt/ros/noetic/setup.bash
# source ~/robotics_ws/devel/setup.bash
# export ROS_PACKAGE_PATH=~/robotics_ws/src:/opt/ros/noetic/share
# export ROS_HOSTNAME=`hostname` # note these are backticks, not apostrophes
# export ROS_MASTER_URI=http://roboticsX:11311 # replace 'X' with label of your NUC
# ```
#
# Any time you make changes to your `~/.bashrc` file you must source it:
#
# ```bash
# source ~/.bashrc
# ```
#
# #### Dependencies
# There are a number of ROS packages required to operate the USAFABot. To ensure ROS message compatibility you will want all of these libraries to be downloaded on your desktop as well. Some of these can be installed using `apt install` and others have to be installed from source. Change directories to your source folder and follow the below steps to install each dependency.
#
# ##### [USAFABot](https://github.com/AF-ROBOTICS/usafabot)
# ```bash
# cd ~/robotics_ws/src
# git clone git@github.com:AF-ROBOTICS/usafabot.git
# cd ..
# catkin_make
# ```
#
#
#
# If you have compile errors, you may need to install the following packages
# ```bash
# sudo apt install ros-noetic-amcl
# sudo apt install ros-noetic-apriltag-ros
# sudo apt install ros-noetic-slam-gmapping
# sudo apt install ros-noetic-teleop-twist-keyboard
# ```
#
# ```bash
# cd ~/robotics_ws/src
# git clone git@github.com:Slamtec/rplidar_ros.git
# cd ~/robotics_ws
# catkin_make
# ```
#
#
# ```bash
# cd ~/robotics_ws/src
# git clone https://github.com/ros-drivers/um7.git
# cd ~/robotics_ws
# rosdep install --from-paths src --ignore-src -r -y
# catkin_make
# ```
#
# ##### [Serial](http://wjwwood.io/serial/)
#
# ```bash
# cd ~/robotics_ws/src
# git clone https://github.com/wjwwood/serial
# ```
#
#
# This will take a while.
#
# Now we can make and source our workspace:
#
# ```bash
# cd ~/robotics_ws
# catkin_make
# source ~/.bashrc
# ```

# %% [markdown]
# ### Installing Jupyter-Notebook For Documentation (Personal Computer / Cadet Laptop) TODO: Should probably change instructions from Teams to GIT
# 1. Download Py-Charm edu from their [Educational Website](https://www.jetbrains.com/edu-products/download/#section=pycharm-edu)
#
#
# 1. Download Windows Terminal from the [Microsoft Store](https://www.microsoft.com/en-US/p/windows-terminal/9n0dx20hk701?activetab=pivot:overviewtab)
#
#
# 1. Open Windows Terminal on your computer.
#
#
# 1. Check what version of python you have installed. It should be **3.8**. exit() python when finished.
#
#     <img src="./Images/py_check.png">
#
# 1. Install jupyter-notebook.
#
#     <img src="./Images/install_notebook.PNG">
#
# 1. When installing, you will see yellow text with an error saying a path is not current. i.e. C:\Users\CadetName\...
#
#
# 1. Copy the path that was not active and in your computer settings go *System->About->Advanced System Settings*.
#
#
# 1. Go to Environment Variables.
#
#     <img src="./Images/envvar.PNG">
#
# 1. Select the *Path* variable under variables for cadet_admin and click *Edit*.
#
#     <img src="./Images/path1.png">
#
# 1. Select *New* and *paste* path copied from *step 6*.
#
#     <img src"" alt="path2.png is not in the github">
#
# 1. Repeat steps 9-10 for *path* within the *system variables*.
#
#
# 1. Click *Okay* and exit out of all settings.
#
#
# 1. Close Windows Terminal.
#
#
# 1. Go to the *Capstone Team's Page->Files*.
#
#
# 1. Hit Sync and proceed with instructions.
#
#     <img src="./Images/sync.png">
#
# 1. After files have synched, navigate to the *Capstone_Documentation* in your local file browser. There should be a little office building for the folder.
#
# 1. Right Click in the folder and click *Open in Windows Terminal*
# <br/>
#
# 1. In windows termial, type *jupyter-notebook*
#
#     <img src="./Images/notebook1.png">
#
# 1. Jupyter-Notebook will open in your prefered browser. You can now access all documentation notebooks and edit with jupyter-notebook.
#
#
# 1. For a tutorial on how to use it, look at [this helpful website](https://www.dataquest.io/blog/jupyter-notebook-tutorial/).
